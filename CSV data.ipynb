# %%
##TO CALCULATE PERCENT CHANGE ON YOY,WE NEED TO SUBRACT EACH DECIMAL VALUE IN CELL BY 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('EV growth.csv',encoding='latin-1')

# %%
df.head()
# Out:
#   Month     Japan  North America  South America    Europe  Middle East/Africa  \
# 0   Jan  1.891501       1.577925       4.304348  1.498321            1.700000
# 1   Feb  1.618199       1.950183       0.883436  1.555441            4.736111
# 2   Mar  1.381821       1.031914       3.425000  1.722711            1.272152
# 3   Apr  2.081836       0.783442       7.926829  1.537549            3.419355
# 4   May  1.877160       0.872887      20.357143  1.341045            3.536585
#
#    Asia & Oceanea     China      Period  sub Electrified vehicle sales total
# 0        2.385847  1.127542  31-01-2024  1.0                          160.8%
# 1        1.359230  0.316580  28-02-2024  1.0                          126.6%
# 2        1.248142  0.433492  30-03-2024  1.0                          104.9%
# 3        1.365041  0.448959  30-04-2024  1.0                           92.9%
# 4        1.880376  0.456552  30-05-2024  1.0                           96.0%

# %%
df.dtypes
# Out:
# Month                               object
# Japan                              float64
# North America                      float64
# South America                      float64
# Europe                             float64
# Middle East/Africa                 float64
# Asia & Oceanea                     float64
# China                              float64
# Period                              object
# sub                                float64
# Electrified vehicle sales total     object
# dtype: object

# %%
df['Electrified vehicle sales total'] = df['Electrified vehicle sales total'].str.rstrip('%').astype(float) / 100

# %%
df.dtypes
# Out:
# Month                               object
# Japan                              float64
# North America                      float64
# South America                      float64
# Europe                             float64
# Middle East/Africa                 float64
# Asia & Oceanea                     float64
# China                              float64
# Period                              object
# sub                                float64
# Electrified vehicle sales total    float64
# dtype: object

# %%
df.head()
# Out:
#   Month     Japan  North America  South America    Europe  Middle East/Africa  \
# 0   Jan  1.891501       1.577925       4.304348  1.498321            1.700000
# 1   Feb  1.618199       1.950183       0.883436  1.555441            4.736111
# 2   Mar  1.381821       1.031914       3.425000  1.722711            1.272152
# 3   Apr  2.081836       0.783442       7.926829  1.537549            3.419355
# 4   May  1.877160       0.872887      20.357143  1.341045            3.536585
#
#    Asia & Oceanea     China      Period  sub  Electrified vehicle sales total
# 0        2.385847  1.127542  31-01-2024  1.0                            1.608
# 1        1.359230  0.316580  28-02-2024  1.0                            1.266
# 2        1.248142  0.433492  30-03-2024  1.0                            1.049
# 3        1.365041  0.448959  30-04-2024  1.0                            0.929
# 4        1.880376  0.456552  30-05-2024  1.0                            0.960

# %%
df.applymap(lambda x: x - 1 if isinstance(x, float) else x)
# Out:
# C:\Users\Jacinto\AppData\Local\Temp\ipykernel_23032\2094165847.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x - 1 if isinstance(x, float) else x)
#    Month     Japan  North America  South America    Europe  \
# 0    Jan  0.891501       0.577925       3.304348  0.498321
# 1    Feb  0.618199       0.950183      -0.116564  0.555441
# 2    Mar  0.381821       0.031914       2.425000  0.722711
# 3    Apr  1.081836      -0.216558       6.926829  0.537549
# 4    May  0.877160      -0.127113      19.357143  0.341045
# 5    Jun  0.672425      -0.060535      33.375000  0.232572
# 6    Jul  0.527471       0.057617      93.333333  0.226846
# 7    Aug  0.392768       0.420651       3.779412  0.406928
# 8    Sep  0.228730       0.168678      10.518519  0.243081
# 9    Oct -0.029608       0.342889       4.606061  0.012316
# 10   NaN       NaN            NaN            NaN       NaN
# ...

# %%
df.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23032\3155841358.py in ?()
# ----> 1 df.show
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23032\3726558592.py in ?()
# ----> 1 df.show()
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
df.head(9)
# Out:
#   Month     Japan  North America  South America    Europe  Middle East/Africa  \
# 0   Jan  1.891501       1.577925       4.304348  1.498321            1.700000
# 1   Feb  1.618199       1.950183       0.883436  1.555441            4.736111
# 2   Mar  1.381821       1.031914       3.425000  1.722711            1.272152
# 3   Apr  2.081836       0.783442       7.926829  1.537549            3.419355
# 4   May  1.877160       0.872887      20.357143  1.341045            3.536585
# 5   Jun  1.672425       0.939465      34.375000  1.232572            2.729167
# 6   Jul  1.527471       1.057617      94.333333  1.226846            4.500000
# 7   Aug  1.392768       1.420651       4.779412  1.406928            1.684211
# 8   Sep  1.228730       1.168678      11.518519  1.243081            1.219178
#
#    Asia & Oceanea     China      Period  sub  Electrified vehicle sales total
# 0        2.385847  1.127542  31-01-2024  1.0                            1.608
# ...

# %%
df_modified = df.map(lambda x: x - 1 if isinstance(x, float) else x)

# %%
display(df_modified)
# Out:
#    Month     Japan  North America  South America    Europe  \
# 0    Jan  0.891501       0.577925       3.304348  0.498321
# 1    Feb  0.618199       0.950183      -0.116564  0.555441
# 2    Mar  0.381821       0.031914       2.425000  0.722711
# 3    Apr  1.081836      -0.216558       6.926829  0.537549
# 4    May  0.877160      -0.127113      19.357143  0.341045
# 5    Jun  0.672425      -0.060535      33.375000  0.232572
# 6    Jul  0.527471       0.057617      93.333333  0.226846
# 7    Aug  0.392768       0.420651       3.779412  0.406928
# 8    Sep  0.228730       0.168678      10.518519  0.243081
# 9    Oct -0.029608       0.342889       4.606061  0.012316
# 10   NaN       NaN            NaN            NaN       NaN
# 11   NaN       NaN            NaN            NaN       NaN
# 12   NaN       NaN            NaN            NaN       NaN
# 13   NaN       NaN            NaN            NaN       NaN
# 14   NaN       NaN            NaN            NaN       NaN
# ...

# %%
 df_modified.to_csv('ev_growth.csv', index=False)
 print(f"Modified CSV file saved at: {ev_growth.csv}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 df_modified.to_csv('ev_growth.csv', index=False)
# ----> 2 print(f"Modified CSV file saved at: {ev_growth.csv}")
#
# NameError: name 'ev_growth' is not defined

# %%
df_modified
# Out:
#    Month     Japan  North America  South America    Europe  \
# 0    Jan  0.891501       0.577925       3.304348  0.498321
# 1    Feb  0.618199       0.950183      -0.116564  0.555441
# 2    Mar  0.381821       0.031914       2.425000  0.722711
# 3    Apr  1.081836      -0.216558       6.926829  0.537549
# 4    May  0.877160      -0.127113      19.357143  0.341045
# 5    Jun  0.672425      -0.060535      33.375000  0.232572
# 6    Jul  0.527471       0.057617      93.333333  0.226846
# 7    Aug  0.392768       0.420651       3.779412  0.406928
# 8    Sep  0.228730       0.168678      10.518519  0.243081
# 9    Oct -0.029608       0.342889       4.606061  0.012316
# 10   NaN       NaN            NaN            NaN       NaN
# 11   NaN       NaN            NaN            NaN       NaN
# 12   NaN       NaN            NaN            NaN       NaN
# 13   NaN       NaN            NaN            NaN       NaN
# 14   NaN       NaN            NaN            NaN       NaN
# ...

# %%
 df_modified.to_csv('ev_growth', index=False)

# %%
df_saved = pd.read_csv('ev_growth')

# %%
df_saved
# Out:
#    Month     Japan  North America  South America    Europe  \
# 0    Jan  0.891501       0.577925       3.304348  0.498321
# 1    Feb  0.618199       0.950183      -0.116564  0.555441
# 2    Mar  0.381821       0.031914       2.425000  0.722711
# 3    Apr  1.081836      -0.216558       6.926829  0.537549
# 4    May  0.877160      -0.127113      19.357143  0.341045
# 5    Jun  0.672425      -0.060535      33.375000  0.232572
# 6    Jul  0.527471       0.057617      93.333333  0.226846
# 7    Aug  0.392768       0.420651       3.779412  0.406928
# 8    Sep  0.228730       0.168678      10.518519  0.243081
# 9    Oct -0.029608       0.342889       4.606061  0.012316
# 10   NaN       NaN            NaN            NaN       NaN
# 11   NaN       NaN            NaN            NaN       NaN
# 12   NaN       NaN            NaN            NaN       NaN
# 13   NaN       NaN            NaN            NaN       NaN
# 14   NaN       NaN            NaN            NaN       NaN
# ...

# %%
df=pd.read_csv('ev_growth'.csv',encoding='latin-1')
